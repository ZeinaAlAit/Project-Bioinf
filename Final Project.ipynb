# %% [markdown]
# # Final Project (*^▽^*)

# %% [markdown]
# >first question

# %% [markdown]
# <a id="anchor"></a>
# ### A car with a full tank of gas drives 80 miles per hour for 3 hours before running out of gas. How many miles can the car go per tank?

# %%
speed = 80 
time = 3 

distance = time * speed 
print ("The car can go ", distance, " miles per tank.")
# Out:
# The car can go  240  miles per tank.

# %% [markdown]
# **plot using matplotlib**

# %% [markdown]
# *here it is*

# %%
import matplotlib.pyplot as plt

plt.plot([0, time], [0, distance], color="pink")
plt.title('Distance vs Time')
plt.xlabel('Time (hours)')
plt.ylabel('Distance (miles)')
plt.show()

# %% [markdown]
# >second question

# %% [markdown]
# ### A runner travels a half marathon (13.1 miles) in 3 hours. How fast was this runner going in miles per hour?

# %%
distance = 13.1 
time = 3.0 

speed = distance / time 

print("Therefore, the runner was going at a speed of", round(speed, 2), "miles per hour.")
# Out:
# Therefore, the runner was going at a speed of 4.37 miles per hour.

# %% [markdown]
# >third question

# %% [markdown]
# ### The spread of a virus is exponential. If 5 people are infected and each person infects 2 other people, how many people have been infected after 5 rounds of infection?

# %%
infected = 5
multiplier = 2
total_infected = infected

for i in range(1, 6):
    infected *= multiplier
    total_infected += infected

print("Total number of infected people after 5 rounds:", total_infected)
# Out:
# Total number of infected people after 5 rounds: 315

# %% [markdown]
# ---

# %% [markdown]
# ##### skip to frist question
# [Go to anchor](#anchor)

# %% [markdown]
# #### favourite shows
# - Family guy
# - Modern Family
# - Breaking Bad
# - Better Call Saul
# - Sherlock

# %% [markdown]
# ![desktop-wallpaper-family-guy-stewie-brian-and-stewie.jpg](attachment:desktop-wallpaper-family-guy-stewie-brian-and-stewie.jpg)
